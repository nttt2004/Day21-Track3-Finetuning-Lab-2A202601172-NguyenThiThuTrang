# %% [markdown]
# # Lab 21 — Fine-tuning LLMs · RUN ALL (T4)
#
# Chay tu tren xuong. Runtime > Change runtime type > **T4 GPU** truoc khi bat dau.
#
# | O | Lam gi | Thoi gian |
# |---|---|---|
# | 1 | clone + install | ~1 phut |
# | 2 | smoke: import + unit test | ~30 giay |
# | 3 | **core pipeline NB1 -> NB5** | ~80 phut |
# | 4 | gatekeeper + in ket qua | ~10 giay |

# %%
# @title 1. Setup — clone + install (chạy ô này trước)
import os, subprocess, sys

REPO = "https://github.com/hieutrungdao/Day21-Track3-Finetuning-Lab.git"
if not os.path.exists("Day21-Track3-Finetuning-Lab"):
    subprocess.run(["git", "clone", "-q", REPO], check=True)
os.chdir("/content/Day21-Track3-Finetuning-Lab")
subprocess.run(["git", "pull", "-q"], check=False)
sys.path.insert(0, "src")

# Install from requirements.txt, NOT a copied list. The copied list is how the
# torchao>=0.16 pin reached requirements.txt and this bootstrap on different days --
# and a bootstrap missing a pin does not fail here, it fails 10 minutes later inside
# get_peft_model(). One source of truth. torch is preinstalled on Colab and
# requirements.txt pins it compatibly, so that line is a no-op.
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"],
               check=True)

import torch
print("commit :", subprocess.run(["git","rev-parse","--short","HEAD"],
                                 capture_output=True, text=True).stdout.strip())
print("GPU    :", torch.cuda.get_device_name(0) if torch.cuda.is_available()
      else "NONE — Runtime > Change runtime type > T4 GPU")
if torch.cuda.is_available():
    print("VRAM   : %.1f GB" % (torch.cuda.get_device_properties(0).total_memory/1024**3))
# Out:
# commit : 4f619a4
# GPU    : Tesla T4
# VRAM   : 14.6 GB

# %%
# @title 2. Smoke — imports, seed data, unit tests (no GPU needed)
# !python scripts/verify.py --smoke
# Out:
# [  ok  ] labkit imports
# [  ok  ] tier resolves                                    T4 -> unsloth/Qwen3.5-4B
# [  ok  ] all tiers respect the <32 effective-batch rule
# [  ok  ] data/train_seed.jsonl                            250 rows
# [  ok  ] data/eval_target.jsonl                           50 rows
# [  ok  ] data/eval_regression.jsonl                       15 rows
# [  ok  ] unit tests                                       118 passed in 3.93s
#
# 7 passed · 0 warnings · 0 failures
#
# Ready to submit.

# %%
# @title 3. Core pipeline — NB1 → NB5
# EVAL_LIMIT truncates both eval sets: "" = full run (submittable),
# 8 = ~fast smoke pass. STAGES lets you resume after a failure.
import os
COMPUTE_TIER = "T4"        # @param ["CPU","LAPTOP","T4","BIGGPU"]
EVAL_LIMIT   = ""         # @param ["", "4", "8", "16", "25"]
STAGES       = "nb1 nb2 nb3 nb4 nb5"   # @param {type:"string"}

os.environ["COMPUTE_TIER"] = COMPUTE_TIER
if EVAL_LIMIT:
    os.environ["EVAL_LIMIT"] = EVAL_LIMIT
else:
    os.environ.pop("EVAL_LIMIT", None)

from labkit import device
print(device.banner(), "\n")

# !python scripts/colab_run.py {STAGES}
# Out:
# Tesla T4 (cuda, sm_75, 14.6 GB) -> precision=fp16
#   note: this GPU predates Ampere, so it has NO bfloat16. Using fp16 with gradient scaling instead. Tutorials that hardcode bf16=True fail here.
#
# tier=T4  mask=assistant-only  eval_limit=full
#
# ========================================================================
# NB1 — data, chat template & loss mask
# ========================================================================
# tier=T4  model=unsloth/Qwen3.5-4B  max_length=1024
# 250 mẫu huấn luyện
# {
#   "instruction": "Phân loại ticket chăm sóc khách hàng sau thành JSON với đúng 4 khóa: intent, urgency, product, sentiment. Chỉ trả về JSON, không giải thích.\n\nintent thuộc: doi_tra | van_chuyen | hoan_tien | san_pham_loi | hoi_thong_tin\nurgency thuộc: cao | trung_binh | thap\nsentiment thuộc: tieu_cuc | trung_tinh | tich_cuc\nproduct: tên sản phẩm xuất hiện trong ticket.",
#   "input": "Alo sh
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# eos_token: <|im_end|>
# VERDICT: reasoning preserved — safe to train on traces
#
# --- chuỗi đã render ---
# <|im_start|>user
# 2+2?<|im_end|>
# <|im_start|>assistant
# <think>
# buoc 1: kiem tra. buoc 2: tra loi.
# </think>
#
# 4<|im_end|>
#
# ======================================================================
# mode = assistant-only   supervised 39/94 (41%)
# --- LOSS TÍNH TRÊN ĐOẠN NÀY ---
# </think>
#
# {"intent": "doi_tra", "urgency": "trung_binh", "product": "balo laptop", "sentiment": "trung_tinh"}<|im_end|>
#
# ======================================================================
# mode = everything   supervised 94/94 (100%)
# --- LOSS TÍNH TRÊN ĐOẠN NÀY ---
# <|im_start|>system
# Phân loại ticket sau.<|im_end|>
# <|im_start|>user
# Alo shop, mình đặt balo laptop mã đơn VN411453. Cho tôi trả lại. Đã 3 ngày rồi. Cho tôi hỏi.<|im_end|>
# <|im_start|>assistant
# <think>
#
# </think>
#
# {"intent": "doi_tra", "urgency": "trung_binh", "product": "balo laptop", "sentiment": "trung_tinh"}<|im_end|>
#
# {
#   "mask_mode": "assistant-only",
#   "n_supervised": 39,
#   "n_total": 94,
#   "supervised_fraction": 0.4149,
#   "answer_is_supervised": true,
#   "question_is_masked": true
# }
# {
#   "n": 250,
#   "mean": 93.1,
#   "p50": 93,
#   "p95": 98,
#   "p99": 100,
#   "max": 101,
#   "suggested_max_length": 256
# }
#
# ⚠ p95 gợi ý max_length=256 nhưng tier đang đặt 1024. Ghi lại lựa chọn của bạn trong REPORT.md.
# train=225  val=25  -> /content/Day21-Track3-Finetuning-Lab/data/split
#
# -- NB1 ok in 11s
#
# ========================================================================
# NB2 — freeze eval + three baselines
# ========================================================================
# target=50  regression=15  tier=T4
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1389.30it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:32<00:00, 13.23it/s]
#   [(a) base + naive prompt/target] batch 1/13     13s elapsed  ~  161s left
#   [(a) base + naive prompt/target] batch 2/13     26s elapsed  ~  142s left
#   [(a) base + naive prompt/target] batch 3/13     38s elapsed  ~  127s left
#   [(a) base + naive prompt/target] batch 4/13     50s elapsed  ~  113s left
#   [(a) base + naive prompt/target] batch 5/13     63s elapsed  ~  100s left
#   [(a) base + naive prompt/target] batch 6/13     75s elapsed  ~   88s left
#   [(a) base + naive prompt/target] batch 7/13     87s elapsed  ~   75s left
#   [(a) base + naive prompt/target] batch 8/13    100s elapsed  ~   62s left
#   [(a) base + naive prompt/target] batch 9/13    112s elapsed  ~   50s left
#   [(a) base + naive prompt/target] batch 10/13    124s elapsed  ~   37s left
#   [(a) base + naive prompt/target] batch 11/13    136s elapsed  ~   25s left
#   [(a) base + naive prompt/target] batch 12/13    149s elapsed  ~   12s left
#   [(a) base + naive prompt/target] batch 13/13    161s elapsed  ~    0s left
#   [(a) base + naive prompt/target] done: 50 prompts in 161s
#   [(a) base + naive prompt/regression] batch 1/4      5s elapsed  ~   16s left
#   [(a) base + naive prompt/regression] batch 2/4     13s elapsed  ~   13s left
#   [(a) base + naive prompt/regression] batch 3/4     20s elapsed  ~    7s left
#   [(a) base + naive prompt/regression] batch 4/4     28s elapsed  ~    0s left
#   [(a) base + naive prompt/regression] done: 15 prompts in 28s
# (a) base + naive prompt      target=0.000  regression=0.758  format=0.000  3217ms
#   [(b) base + optimized prompt/target] batch 1/13      5s elapsed  ~   56s left
#   [(b) base + optimized prompt/target] batch 2/13      9s elapsed  ~   47s left
#   [(b) base + optimized prompt/target] batch 3/13     12s elapsed  ~   41s left
#   [(b) base + optimized prompt/target] batch 4/13     17s elapsed  ~   38s left
#   [(b) base + optimized prompt/target] batch 5/13     21s elapsed  ~   33s left
#   [(b) base + optimized prompt/target] batch 6/13     25s elapsed  ~   29s left
#   [(b) base + optimized prompt/target] batch 7/13     29s elapsed  ~   25s left
#   [(b) base + optimized prompt/target] batch 8/13     33s elapsed  ~   21s left
#   [(b) base + optimized prompt/target] batch 9/13     37s elapsed  ~   16s left
#   [(b) base + optimized prompt/target] batch 10/13     41s elapsed  ~   12s left
#   [(b) base + optimized prompt/target] batch 11/13     45s elapsed  ~    8s left
#   [(b) base + optimized prompt/target] batch 12/13     49s elapsed  ~    4s left
#   [(b) base + optimized prompt/target] batch 13/13     53s elapsed  ~    0s left
#   [(b) base + optimized prompt/target] done: 50 prompts in 53s
#   [(b) base + optimized prompt/regression] batch 1/4      5s elapsed  ~   14s left
#   [(b) base + optimized prompt/regression] batch 2/4     12s elapsed  ~   12s left
#   [(b) base + optimized prompt/regression] batch 3/4     19s elapsed  ~    6s left
#   [(b) base + optimized prompt/regression] batch 4/4     27s elapsed  ~    0s left
#   [(b) base + optimized prompt/regression] done: 15 prompts in 27s
# (b) base + optimized prompt  target=0.765  regression=0.758  format=1.000  1064ms
# {
#   "tier": "T4",
#   "model": "unsloth/Qwen3.5-4B",
#   "baseline_a": {
#     "target": 0.0,
#     "regression": 0.7577777777777778,
#     "format": 0.0,
#     "latency_ms": 3217.1826580400557,
#     "n": 50,
#     "extra": {}
#   },
#   "baseline_b": {
#     "target": 0.765,
#     "regression": 0.7577777777777778,
#     "format": 1.0,
#     "latency_ms": 1064.2697637799574,
#     "n": 50,
#     "extra": {}
#   },
#   "optimized_prompt_sha": "719e74d3b6232053",
#   "n_target": 50,
#   "n_regression": 15,
#   "eval_limit": null,
#   "smoke_mode": false
# }
#
# -- NB2 ok in 315s
#
# ========================================================================
# NB3 — train the correct configuration
# ========================================================================
# T4 · unsloth/Qwen3.5-4B · all-linear · r=16 · LR 10x · 16-bit
# Tesla T4 (cuda, sm_75, 14.6 GB) -> precision=fp16
#   note: this GPU predates Ampere, so it has NO bfloat16. Using fp16 with gradient scaling instead. Tutorials that hardcode bf16=True fail here.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 999.00it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:32<00:00, 12.95it/s]
# {
#   "num_hidden_layers": 32,
#   "full_attention_interval": 4,
#   "linear_num_key_heads": 16,
#   "layer_types": {
#     "linear_attention": 24,
#     "full_attention": 8
#   }
# }
# placement=text-linear  modules=['down_proj', 'gate_proj', 'in_proj_a', 'in_proj_b', 'in_proj_qkv', 'in_proj_z', 'k_proj', 'o_proj', 'out_proj', 'q_proj', 'up_proj', 'v_proj']
# trainable LoRA params ≈ 32.46 M
#     {'placement': 'text-linear', 'modules': 12, 'r': 16, 'trainable': 32464896}
#     {'placement': 'attn-only(q,v)', 'modules': 2, 'r': 16, 'trainable': 1835008}
#     {'placement': 'attn-only(q,v) matched', 'modules': 2, 'r': 283, 'trainable': 32456704}
# Dataset({
#     features: ['input_ids', 'labels', 'attention_mask'],
#     num_rows: 225
# })
# mask_mode = assistant-only   supervised 9014/20951 tokens (43.0%)
# epochs=2.0  ->  30 optimizer steps  (NB4 runs its contrasts at exactly this many)
# {
#   "output_dir": "/content/Day21-Track3-Finetuning-Lab/adapters/correct",
#   "max_length": "1024",
#   "per_device_train_batch_size": "1",
#   "gradient_accumulation_steps": "16",
#   "learning_rate": "0.0001",
#   "lr_scheduler_type": "cosine",
#   "num_train_epochs": "2.0",
#   "logging_steps": "5",
#   "save_strategy": "no",
#   "report_to": "none",
#   "seed": "42",
#   "packing": "False",
#   "loss_type": "chunked_nll",
#   "gradient_checkpointing": "True",
#   "warmup_steps": "3",
#   "bf16": "False",
#   "fp16": "True",
#   "padding_free": "False"
# }
# Truncating train dataset: 100% 225/225 [00:00<00:00, 8344.77 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 44542.33 examples/s]
# precision fix: {'precision': 'fp16', 'recast': 0, 'trainable_tensors': 496}
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': 'nan', 'learning_rate': '9.966e-05', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '1.386', 'grad_norm': '2.566', 'learning_rate': '8.83e-05', 'entropy': '1.033', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.769', 'epoch': '0.7111'}
# {'loss': '0.1449', 'grad_norm': '0.6107', 'learning_rate': '6.434e-05', 'entropy': '0.2757', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9569', 'epoch': '1'}
# {'loss': '0.03062', 'grad_norm': '0.8769', 'learning_rate': '3.566e-05', 'entropy': '0.04502', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.9882', 'epoch': '1.356'}
# {'loss': '0.02116', 'grad_norm': '0.2615', 'learning_rate': '1.17e-05', 'entropy': '0.02223', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.993', 'epoch': '1.711'}
# {'loss': '0.02689', 'grad_norm': 'nan', 'learning_rate': '3.381e-07', 'entropy': '0.01711', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.9946', 'epoch': '2'}
# {'train_runtime': '977.4', 'train_samples_per_second': '0.46', 'train_steps_per_second': '0.031', 'train_loss': '0.6288', 'epoch': '2'}
# 100% 30/30 [16:17<00:00, 32.58s/it]
# train 978s  final loss 0.6288
# saved -> /content/Day21-Track3-Finetuning-Lab/adapters/correct
# {
#   "run": "correct",
#   "label": "all-linear · r=16 · LR 10x · 16-bit",
#   "tier": "T4",
#   "model": "unsloth/Qwen3.5-4B",
#   "precision": "fp16",
#   "placement": "text-linear",
#   "n_target_modules": 12,
#   "r": 16,
#   "lora_alpha": 32,
#   "learning_rate": 0.0001,
#   "load_in_4bit": false,
#   "trainable_params": 32464896,
#   "train_seconds": 977.8,
#   "peak_vram_gb": 12.01,
#   "final_loss": 0.6288,
#   "mask_mode": "assistant-only",
#   "max_steps": 30
# }
#
# -- NB3 ok in 1035s
#
# ========================================================================
# NB4 — three misconfiguration contrasts
# ========================================================================
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1061.71it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:31<00:00, 13.32it/s]
# | placement | modules | r | trainable |
# |---|---|---|---|
# | text-linear | 12 | 16 | 32464896 |
# | attn-only(q,v) | 2 | 16 | 1835008 |
# | attn-only(q,v) matched | 2 | 283 | 32456704 |
# skip attn_only: adapters/attn_only/ already trained (FORCE_RETRAIN=1 to redo, or delete the directory)
# skip wrong_lr: adapters/wrong_lr/ already trained (FORCE_RETRAIN=1 to redo, or delete the directory)
# skip qlora: adapters/qlora/ already trained (FORCE_RETRAIN=1 to redo, or delete the directory)
# nothing retrained this session — reading runs.csv for the table
# | run | label | r | trainable_params | learning_rate | final_loss | train_seconds | peak_vram_gb |
# |---|---|---|---|---|---|---|---|
# | correct | all-linear · r=16 · LR 10x · 16-bit | 16 | 32464896 | 0.0001 | 0.6288 | 977.8 | 12.01 |
# | attn_only | q,v only · r=matched · LR 10x · 16-bit | 283 | 32456704 | 0.0001 | 0.538 | 817.9 | 12.02 |
# | wrong_lr | all-linear · r=16 · LR 1x (full-FT scale) · 16-bit | 16 | 32464896 | 1e-05 | 1.5704 | 954.2 | 12.01 |
# | qlora | all-linear · r=16 · LR 10x · 4-bit QLoRA | 16 | 32464896 | 0.0001 | 0.7058 | 1011.5 | 7.09 |
#
# -- NB4 ok in 53s
#
# ========================================================================
# NB5 — four-group eval + verdict
# ========================================================================
# baseline (b) target = 0.765 — đây là mốc phải vượt
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1012.38it/s]
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Download complete: :           |  0.00B
# Loading weights: 100% 426/426 [00:32<00:00, 13.06it/s]
#   [ft/target] batch 1/13      6s elapsed  ~   77s left
#   [ft/target] batch 2/13     13s elapsed  ~   70s left
#   [ft/target] batch 3/13     18s elapsed  ~   59s left
#   [ft/target] batch 4/13     24s elapsed  ~   53s left
#   [ft/target] batch 5/13     29s elapsed  ~   46s left
#   [ft/target] batch 6/13     35s elapsed  ~   40s left
#   [ft/target] batch 7/13     40s elapsed  ~   34s left
#   [ft/target] batch 8/13     45s elapsed  ~   28s left
#   [ft/target] batch 9/13     50s elapsed  ~   22s left
#   [ft/target] batch 10/13     56s elapsed  ~   17s left
#   [ft/target] batch 11/13     61s elapsed  ~   11s left
#   [ft/target] batch 12/13     67s elapsed  ~    6s left
#   [ft/target] batch 13/13     73s elapsed  ~    0s left
#   [ft/target] done: 50 prompts in 73s
#   [ft/regression] batch 1/4     11s elapsed  ~   33s left
#   [ft/regression] batch 2/4     22s elapsed  ~   22s left
#   [ft/regression] batch 3/4     34s elapsed  ~   11s left
#   [ft/regression] batch 4/4     47s elapsed  ~    0s left
#   [ft/regression] done: 15 prompts in 47s
# fine-tune: {'target': 0.965, 'regression': 0.45555555555555555, 'format': 1.0, 'latency_ms': 1454.515838599982, 'n': 50, 'extra': {'valid_trace_rate': 0.0}}
# | run | target | regression | format | latency_ms | n |
# |---|---|---|---|---|---|
# | (a) base + naive prompt | 0.0 | 0.7578 | 0.0 | 3217.2 | 50 |
# | (b) base + optimized prompt | 0.765 | 0.7578 | 1.0 | 1064.3 | 50 |
# | (c) LoRA fine-tune | 0.965 | 0.4556 | 1.0 | 1454.5 | 50 |
# FAILED
#  - general capability regressed by 0.302 (tolerance 0.020). See deck §14.3 — add 1-5% replay data.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 949.80it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:31<00:00, 13.44it/s]
#   [attn_only/target] batch 1/13      4s elapsed  ~   48s left
#   [attn_only/target] batch 2/13      7s elapsed  ~   41s left
#   [attn_only/target] batch 3/13     11s elapsed  ~   36s left
#   [attn_only/target] batch 4/13     15s elapsed  ~   33s left
#   [attn_only/target] batch 5/13     18s elapsed  ~   29s left
#   [attn_only/target] batch 6/13     22s elapsed  ~   25s left
#   [attn_only/target] batch 7/13     25s elapsed  ~   21s left
#   [attn_only/target] batch 8/13     29s elapsed  ~   18s left
#   [attn_only/target] batch 9/13     32s elapsed  ~   14s left
#   [attn_only/target] batch 10/13     35s elapsed  ~   11s left
#   [attn_only/target] batch 11/13     39s elapsed  ~    7s left
#   [attn_only/target] batch 12/13     43s elapsed  ~    4s left
#   [attn_only/target] batch 13/13     46s elapsed  ~    0s left
#   [attn_only/target] done: 50 prompts in 46s
# attn_only: target=0.970  format=1.000
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 988.41it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:31<00:00, 13.34it/s]
#   [wrong_lr/target] batch 1/13     21s elapsed  ~  247s left
#   [wrong_lr/target] batch 2/13     40s elapsed  ~  222s left
#   [wrong_lr/target] batch 3/13     61s elapsed  ~  203s left
#   [wrong_lr/target] batch 4/13     80s elapsed  ~  181s left
#   [wrong_lr/target] batch 5/13    101s elapsed  ~  162s left
#   [wrong_lr/target] batch 6/13    121s elapsed  ~  142s left
#   [wrong_lr/target] batch 7/13    142s elapsed  ~  121s left
#   [wrong_lr/target] batch 8/13    162s elapsed  ~  101s left
#   [wrong_lr/target] batch 9/13    182s elapsed  ~   81s left
#   [wrong_lr/target] batch 10/13    202s elapsed  ~   61s left
#   [wrong_lr/target] batch 11/13    222s elapsed  ~   40s left
#   [wrong_lr/target] batch 12/13    242s elapsed  ~   20s left
#   [wrong_lr/target] batch 13/13    262s elapsed  ~    0s left
#   [wrong_lr/target] done: 50 prompts in 262s
# wrong_lr: target=0.000  format=0.000
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1034.86it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:35<00:00, 12.16it/s]
#   [qlora/target] batch 1/13      8s elapsed  ~   91s left
#   [qlora/target] batch 2/13     15s elapsed  ~   81s left
#   [qlora/target] batch 3/13     22s elapsed  ~   73s left
#   [qlora/target] batch 4/13     29s elapsed  ~   66s left
#   [qlora/target] batch 5/13     36s elapsed  ~   58s left
#   [qlora/target] batch 6/13     43s elapsed  ~   50s left
#   [qlora/target] batch 7/13     49s elapsed  ~   42s left
#   [qlora/target] batch 8/13     56s elapsed  ~   35s left
#   [qlora/target] batch 9/13     63s elapsed  ~   28s left
#   [qlora/target] batch 10/13     70s elapsed  ~   21s left
#   [qlora/target] batch 11/13     77s elapsed  ~   14s left
#   [qlora/target] batch 12/13     84s elapsed  ~    7s left
#   [qlora/target] batch 13/13     91s elapsed  ~    0s left
#   [qlora/target] done: 50 prompts in 91s
# qlora: target=0.940  format=1.000
#
# | run | target | format | latency_ms | n |
# |---|---|---|---|---|
# | correct | 0.965 | 1.0 | 1454.5 | 50 |
# | attn_only | 0.97 | 1.0 | 921.3 | 50 |
# | wrong_lr | 0.0 | 0.0 | 5243.8 | 50 |
# | qlora | 0.94 | 1.0 | 1816.5 | 50 |
# --- 3 ca TỆ NHẤT (bắt buộc đưa vào report) ---
# | i | ticket | ft_score | ft_pred |
# |---|---|---|---|
# | 3 | Cho mình hỏi, mình đặt bình giữ nhiệt mã đơn VN804124. Chưa thấy tiền. | 0.75 | {"intent": "hoan_tien", "urgency": "trung_binh", "product": "bình giữ nhiệt", "sentiment": |
# | 5 | Shop ơi, mình đặt nồi chiên không dầu mã đơn DH249548. Thiếu phụ kiện. | 0.75 | {"intent": "san_pham_loi", "urgency": "trung_binh", "product": "nồi chiên không dầu", "sen |
# | 12 | Shop ơi, mình đặt áo khoác gió mã đơn VN613097. Bị lỗi. Khi nào tiện.  | 0.75 | {"intent": "san_pham_loi", "urgency": "trung_binh", "product": "áo khoác gió", "sentiment" |
#
# --- 3 ca TỐT NHẤT ---
# | i | ticket | ft_score | ft_pred |
# |---|---|---|---|
# | 47 | Cho mình hỏi, mình đặt ốp lưng điện thoại mã đơn DH936478. Shipper khô | 1.0 | {"intent": "van_chuyen", "urgency": "thap", "product": "ốp lưng điện thoại", "sentiment":  |
# | 48 | Alo shop, mình đặt ốp lưng điện thoại mã đơn DH734695. Giá bao nhiêu.  | 1.0 | {"intent": "hoi_thong_tin", "urgency": "trung_binh", "product": "ốp lưng điện thoại", "sen |
# | 49 | Chào shop, mình đặt ốp lưng điện thoại mã đơn VN833689. Sai màu. Sớm n | 1.0 | {"intent": "san_pham_loi", "urgency": "trung_binh", "product": "ốp lưng điện thoại", "sent |
#
# -- NB5 ok in 683s
#
# ----------------------------------------
# stage timings
#   nb1        11s  (0.2 min)
#   nb2       315s  (5.2 min)
#   nb3      1035s  (17.2 min)
#   nb4        53s  (0.9 min)
#   nb5       683s  (11.4 min)
#   total    2097s (35.0 min)

# %%
# @title 4. Gatekeeper + results
# !python scripts/verify.py
print("\n================ results/ ================")
# !ls -la results/
# !echo && echo "---- runs.csv ----" && cat results/runs.csv 2>/dev/null
# !echo && echo "---- verdict.json ----" && cat results/verdict.json 2>/dev/null
# Out:
# [  ok  ] labkit imports
# [  ok  ] tier resolves                                    T4 -> unsloth/Qwen3.5-4B
# [  ok  ] all tiers respect the <32 effective-batch rule
# [  ok  ] data/train_seed.jsonl                            250 rows
# [  ok  ] data/eval_target.jsonl                           50 rows
# [  ok  ] data/eval_regression.jsonl                       15 rows
# [  ok  ] unit tests                                       118 passed in 2.30s
# [  ok  ] results/template_check.json
# [  ok  ] results/mask_proof.json
# [  ok  ] results/token_stats.json
# [  ok  ] results/baselines_frozen.json
# [  ok  ] results/runs.csv
# [  ok  ] results/verdict.json
# [  ok  ] results/autopsy.json
# [  ok  ] submission/REPORT.md
# [ FAIL ] REPORT.md filled in                              6 placeholders still present (<điền>, <paste>, ...) — this is still the template
# [  ok  ] mask proof asserts
# [  ok  ] full eval set used                               50 target items
# [  ok  ] baseline (b) prompt unmodified
# [  ok  ] baseline (b) beats (a)                           (a)=0.000 -> (b)=0.765
# [  ok  ] eval sets unmodified
# [  ok  ] NB3 run present
# [  ok  ] NB4 contrast runs
# [  ok  ] all runs share ONE step budget                   ['attn_only', 'correct', 'qlora', 'wrong_lr'] at 30 steps
# [  ok  ] attn_only is a FAIR contrast                     32,456,704 vs 32,464,896 trainable params
# [  ok  ] verdict recorded                                 FAILED (target Δ +0.200, regression Δ -0.302)
# [ warn ] note                                             A FAILED verdict is fully gradeable — analyse it honestly in REPORT.md rather than loosening the gate.
#
# 25 passed · 1 warnings · 1 failures
#
# Not ready to submit — fix the FAILs above.
#
# ================ results/ ================
# total 52
# drwxr-xr-x  2 root root  4096 Aug 21 06:00 .
# drwxr-xr-x 16 root root  4096 Aug 21 06:02 ..
# -rw-r--r--  1 root root   434 Aug 21 07:02 autopsy.json
# -rw-r--r--  1 root root   516 Aug 21 06:32 baselines_frozen.json
# -rw-r--r--  1 root root     0 Aug 21 04:18 .gitkeep
# -rw-r--r--  1 root root   592 Aug 21 06:27 mask_proof.json
# -rw-r--r--  1 root root 13678 Aug 21 07:02 qualitative.json
# -rw-r--r--  1 root root  1410 Aug 21 06:50 runs.csv
# -rw-r--r--  1 root root   277 Aug 21 06:27 template_check.json
# -rw-r--r--  1 root root   115 Aug 21 06:27 token_stats.json
# -rw-r--r--  1 root root   806 Aug 21 06:53 verdict.json
#
# ---- runs.csv ----
# run,label,tier,model,precision,placement,n_target_modules,r,lora_alpha,learning_rate,load_in_4bit,trainable_params,train_seconds,peak_vram_gb,final_loss,mask_mode,max_steps,teaches
# correct,all-linear · r=16 · LR 10x · 16-bit,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,0.0001,False,32464896,962.6,12.01,0.6261,assistant-only,30,
# attn_only,"q,v only · r=matched · LR 10x · 16-bit",T4,unsloth/Qwen3.5-4B,fp16,attn-only,2,283,566,0.0001,False,32456704,817.9,12.02,0.538,,30,"Mistake #1 (§10.2): attention-only placement, rank raised to *match parameter count*. If rank were the lever, this would win."
# wrong_lr,all-linear · r=16 · LR 1x (full-FT scale) · 16-bit,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,1e-05,False,32464896,954.2,12.01,1.5704,,30,Mistake #2 (§10.3): a full-fine-tune learning rate applied to LoRA.
# qlora,all-linear · r=16 · LR 10x · 4-bit QLoRA,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,0.0001,True,32464896,1011.5,7.09,0.7058,,30,The vendor says do NOT use QLoRA on Qwen3.5 (§12). Measure the cost yourself instead of taking either side on faith.
# correct,all-linear · r=16 · LR 10x · 16-bit,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,0.0001,False,32464896,930.0,12.01,0.627,assistant-only,30,
# correct,all-linear · r=16 · LR 10x · 16-bit,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,0.0001,False,32464896,977.8,12.01,0.6288,assistant-only,30,
#
# ---- verdict.json ----
# {
#   "comparison": [
#     {
#       "run": "(a) base + naive prompt",
#       "target": 0.0,
#       "regression": 0.7578,
#       "format": 0.0,
#       "latency_ms": 3217.2,
#       "n": 50
#     },
#     {
#       "run": "(b) base + optimized prompt",
#       "target": 0.765,
#       "regression": 0.7578,
#       "format": 1.0,
#       "latency_ms": 1064.3,
#       "n": 50
#     },
#     {
#       "run": "(c) LoRA fine-tune",
#       "target": 0.965,
#       "regression": 0.4556,
#       "format": 1.0,
#       "latency_ms": 1454.5,
#       "n": 50
#     }
#   ],
#   "verdict": {
#     "passed": false,
#     "reasons": [
#       "general capability regressed by 0.302 (tolerance 0.020). See deck §14.3 — add 1-5% replay data."
#     ],
#     "target_delta": 0.19999999999999996,
#     "regression_delta": -0.3022222222222222
#   },
#   "valid_trace_rate": 0.0
# }
